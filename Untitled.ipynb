# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
picasso = pd.read_csv('picasso.csv')

# %%
picasso.head()
# Out:
#      artist_name artist_nationality  artist_birth_year  artist_death_year  \
# 0  Pablo Picasso            Spanish               1881               1973
# 1  Pablo Picasso            Spanish               1881               1973
# 2  Pablo Picasso            Spanish               1881               1973
# 3  Pablo Picasso            Spanish               1881               1973
# 4  Pablo Picasso            Spanish               1881               1973
#
#   auction_house auction_sale_id auction_department auction_location  \
# 0      Sothebys          N09963    Decorative Arts         New York
# 1      Sothebys          N09963    Decorative Arts         New York
# 2      Sothebys          N09963    Decorative Arts         New York
# 3      Sothebys          N09963    Decorative Arts         New York
# 4      Sothebys          N09963    Decorative Arts         New York
#
#                  auction_date auction_currency      ...       \
# ...

# %%
mask = picasso.hammer_price != -1

# %%
np.sort(picasso.auction_date)[-1]
# Out:
# '2018-12-06T19:00:00.928000'

# %%
plt.plot(picasso.auction_date[mask], picasso.hammer_price[mask])

# %%
plt.plot(picasso[['work_execution_year', 'hammer_price']][mask].sort_values(by=['work_execution_year'])['work_execution_year'],
         picasso[['work_execution_year', 'hammer_price']][mask].sort_values(by=['work_execution_year'])['hammer_price'])


plt.xlim(1900,2000)
# Out:
# (1900, 2000)

# %%
lewitt = pd.read_csv('lewitt.csv')

# %%
lewitt.head()
# Out:
#   artist_name artist_nationality  artist_birth_year  artist_death_year  \
# 0  Sol Lewitt           American               1928               2007
# 1  Sol Lewitt           American               1928               2007
# 2  Sol Lewitt           American               1928               2007
# 3  Sol Lewitt           American               1928               2007
# 4  Sol Lewitt           American               1928               2007
#
#   auction_house auction_sale_id       auction_department auction_location  \
# 0     Christies           15910  Post-War & Contemporary        Amsterdam
# 1     Christies           15910  Post-War & Contemporary        Amsterdam
# 2     Christies           15976  Post-War & Contemporary         New York
# 3     Christies           15976  Post-War & Contemporary         New York
# 4     Christies           15976  Post-War & Contemporary         New York
#
#           auction_date auction_currency      ...       work_execution_year  \
# ...
